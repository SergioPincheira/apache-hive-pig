# %% [markdown]
# # Apache Hive

# %% [markdown]
# ## Instalación de ambiente

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
exec(open('/content/drive/MyDrive/Proyectos/apache-hive-pig/hadoop_colab_installer.py').read())
# Out:
# Active services:
# 2424 ResourceManager
# 2568 DataNode
# 2699 JobHistoryServer
# 2734 Jps
# 2494 NameNode
# 2655 NodeManager

# %% [markdown]
# ## Actividad 0: Creación de dos directorios en HDFS y tablas

# %%
# !hdfs dfs -mkdir mp1_df1
# !hdfs dfs -put /content/drive/MyDrive/Proyectos/apache-hive-pig/userid-timestamp-artid-artname-traid-traname.tsv mp1_df1

# !hdfs dfs -mkdir mp1_df2
# !hdfs dfs -put /content/drive/MyDrive/Proyectos/apache-hive-pig/userid-profile.tsv mp1_df2

# %%
# !hdfs dfs -ls /user/root/mp1_df1
# Out:
# Found 1 items
# -rw-r--r--   1 root supergroup 2529193595 2024-11-11 05:50 /user/root/mp1_df1/userid-timestamp-artid-artname-traid-traname.tsv

# %%
# !hdfs dfs -ls /user/root/mp1_df2
# Out:
# Found 1 items
# -rw-r--r--   1 root supergroup      37842 2024-11-11 05:50 /user/root/mp1_df2/userid-profile.tsv

# %%
# %%writefile create_table1.sql
# -- Creación de la tabla para los eventos de escucha
# CREATE EXTERNAL TABLE lastfm_listens (
#     user_id STRING,
#     event_timestamp STRING,
#     artist_id STRING,
#     artist_name STRING,
#     track_id STRING,
#     track_name STRING
# )
# ROW FORMAT DELIMITED
# FIELDS TERMINATED BY '\t'
# STORED AS TEXTFILE
# LOCATION '/user/root/mp1_df1';
# Out:
# Writing create_table1.sql

# %%
# !hive -f create_table1.sql
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
#
# Logging initialized using configuration in jar:file:/content/apache-hive-2.3.9-bin/lib/hive-common-2.3.9.jar!/hive-log4j2.properties Async: true
# OK
# Time taken: 9.232 seconds

# %%
# %%writefile create_table2.sql
# -- Creación de la tabla para los perfiles de usuarios
# CREATE EXTERNAL TABLE  lastfm_users (
#     user_id STRING,
#     gender STRING,
#     age INT,
#     country STRING,
#     registered STRING
# )
# ROW FORMAT DELIMITED
# FIELDS TERMINATED BY '\t'
# STORED AS TEXTFILE
# LOCATION '/user/root/mp1_df2';
# Out:
# Writing create_table2.sql

# %%
# !hive -f create_table2.sql
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
#
# Logging initialized using configuration in jar:file:/content/apache-hive-2.3.9-bin/lib/hive-common-2.3.9.jar!/hive-log4j2.properties Async: true
# OK
# Time taken: 10.573 seconds

# %% [markdown]
# ## Actividad 1: Artista más popular

# %%
# %%writefile actividad1.sql
# -- Consulta para el Top-10 de los artistas más escuchados
# SELECT artist_name, COUNT(*) AS plays
# FROM lastfm_listens
# GROUP BY artist_name
# ORDER BY plays DESC
# LIMIT 10;
# Out:
# Writing actividad1.sql

# %%
# !hive -f actividad1.sql
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
#
# Logging initialized using configuration in jar:file:/content/apache-hive-2.3.9-bin/lib/hive-common-2.3.9.jar!/hive-log4j2.properties Async: true
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20241111055137_bdcc90de-dbe7-4465-b562-4ae724471d4b
# Total jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 10
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1731303223095_0001, Tracking URL = http://e6c4e6359247:8088/proxy/application_1731303223095_0001/
# Kill Command = /content/hadoop/bin/hadoop job  -kill job_1731303223095_0001
# Hadoop job information for Stage-1: number of mappers: 10; number of reducers: 10
# 2024-11-11 05:52:07,061 Stage-1 map = 0%,  reduce = 0%
# 2024-11-11 05:53:02,968 Stage-1 map = 7%,  reduce = 0%, Cumulative CPU 36.06 sec
# 2024-11-11 05:53:04,350 Stage-1 map = 17%,  reduce = 0%, Cumulative CPU 38.91 sec
# 2024-11-11 05:53:05,610 Stage-1 map = 20%,  reduce = 0%, Cumulative CPU 41.85 sec
# 2024-11-11 05:53:13,894 Stage-1 map = 27%,  reduce = 0%, Cumulative CPU 47.38 sec
# 2024-11-11 05:53:15,180 Stage-1 map = 33%,  reduce = 0%, Cumulative CPU 50.24 sec
# 2024-11-11 05:53:16,339 Stage-1 map = 47%,  reduce = 0%, Cumulative CPU 53.48 sec
# 2024-11-11 05:53:17,548 Stage-1 map = 50%,  reduce = 0%, Cumulative CPU 56.15 sec
# 2024-11-11 05:53:19,827 Stage-1 map = 53%,  reduce = 0%, Cumulative CPU 56.68 sec
# 2024-11-11 05:53:20,995 Stage-1 map = 60%,  reduce = 0%, Cumulative CPU 57.94 sec
# 2024-11-11 05:53:53,243 Stage-1 map = 60%,  reduce = 2%, Cumulative CPU 58.32 sec
# 2024-11-11 05:53:57,682 Stage-1 map = 63%,  reduce = 4%, Cumulative CPU 71.11 sec
# 2024-11-11 05:53:58,785 Stage-1 map = 67%,  reduce = 4%, Cumulative CPU 77.78 sec
# 2024-11-11 05:54:01,074 Stage-1 map = 73%,  reduce = 6%, Cumulative CPU 80.58 sec
# 2024-11-11 05:54:03,405 Stage-1 map = 80%,  reduce = 6%, Cumulative CPU 83.2 sec
# 2024-11-11 05:54:04,503 Stage-1 map = 90%,  reduce = 6%, Cumulative CPU 85.9 sec
# 2024-11-11 05:54:05,527 Stage-1 map = 90%,  reduce = 7%, Cumulative CPU 85.97 sec
# 2024-11-11 05:54:06,597 Stage-1 map = 90%,  reduce = 8%, Cumulative CPU 86.06 sec
# 2024-11-11 05:54:09,838 Stage-1 map = 90%,  reduce = 9%, Cumulative CPU 86.13 sec
# 2024-11-11 05:54:22,047 Stage-1 map = 97%,  reduce = 9%, Cumulative CPU 92.2 sec
# 2024-11-11 05:54:23,190 Stage-1 map = 100%,  reduce = 13%, Cumulative CPU 93.17 sec
# 2024-11-11 05:54:24,312 Stage-1 map = 100%,  reduce = 16%, Cumulative CPU 93.78 sec
# 2024-11-11 05:54:27,753 Stage-1 map = 100%,  reduce = 20%, Cumulative CPU 95.51 sec
# 2024-11-11 05:54:31,203 Stage-1 map = 100%,  reduce = 28%, Cumulative CPU 102.13 sec
# 2024-11-11 05:54:33,718 Stage-1 map = 100%,  reduce = 39%, Cumulative CPU 106.26 sec
# 2024-11-11 05:54:35,051 Stage-1 map = 100%,  reduce = 49%, Cumulative CPU 109.88 sec
# 2024-11-11 05:54:36,324 Stage-1 map = 100%,  reduce = 50%, Cumulative CPU 110.31 sec
# 2024-11-11 05:54:57,502 Stage-1 map = 100%,  reduce = 57%, Cumulative CPU 112.98 sec
# 2024-11-11 05:54:59,891 Stage-1 map = 100%,  reduce = 60%, Cumulative CPU 113.7 sec
# 2024-11-11 05:55:05,451 Stage-1 map = 100%,  reduce = 70%, Cumulative CPU 117.08 sec
# 2024-11-11 05:55:06,608 Stage-1 map = 100%,  reduce = 80%, Cumulative CPU 120.74 sec
# 2024-11-11 05:55:07,733 Stage-1 map = 100%,  reduce = 90%, Cumulative CPU 124.07 sec
# 2024-11-11 05:55:08,848 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 127.6 sec
# MapReduce Total cumulative CPU time: 2 minutes 7 seconds 600 msec
# Ended Job = job_1731303223095_0001
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1731303223095_0002, Tracking URL = http://e6c4e6359247:8088/proxy/application_1731303223095_0002/
# Kill Command = /content/hadoop/bin/hadoop job  -kill job_1731303223095_0002
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2024-11-11 05:55:24,936 Stage-2 map = 0%,  reduce = 0%
# 2024-11-11 05:55:33,381 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 4.61 sec
# 2024-11-11 05:55:41,829 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 6.76 sec
# MapReduce Total cumulative CPU time: 6 seconds 760 msec
# Ended Job = job_1731303223095_0002
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 10  Reduce: 10   Cumulative CPU: 127.6 sec   HDFS Read: 2529346768 HDFS Write: 6290492 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 6.76 sec   HDFS Read: 6298398 HDFS Write: 387 SUCCESS
# Total MapReduce CPU Time Spent: 2 minutes 14 seconds 360 msec
# OK
# artist_name	plays
# Radiohead	115209
# The Beatles	100338
# Nine Inch Nails	84421
# Muse	63351
# Coldplay	62251
# Depeche Mode	59910
# Pink Floyd	58561
# Death Cab For Cutie	58083
# Placebo	53543
# Elliott Smith	50278
# Time taken: 246.52 seconds, Fetched: 10 row(s)

# %% [markdown]
# El más popular de este top 10 es Radiohead con 115209 plays y el menos popular del top es Elliott Smith con 50278 plays.

# %% [markdown]
# ## Actividad 2: Distribución por género

# %%
# %%writefile actividad2.sql
#
# SELECT gender, COUNT( l.user_id) AS listeners
# FROM lastfm_listens l
# JOIN lastfm_users u ON l.user_id = u.user_id
# WHERE l.artist_name = 'Radiohead' AND gender !=''
# GROUP BY gender;
# Out:
# Writing actividad2.sql

# %%
# !hive -f actividad2.sql
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
#
# Logging initialized using configuration in jar:file:/content/apache-hive-2.3.9-bin/lib/hive-common-2.3.9.jar!/hive-log4j2.properties Async: true
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20241111055552_c3412097-7427-488a-bd66-47f2faff4e78
# Total jobs = 1
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# 2024-11-11 05:56:17	Starting to launch local task to process map join;	maximum memory = 477626368
# 2024-11-11 05:56:19	Dump the side-table for tag: 1 with group count: 885 into file: file:/tmp/root/bff1cb4e-e35a-4cd3-9ca2-729190a7d8d1/hive_2024-11-11_05-55-52_307_9126435370141163622-1/-local-10005/HashTable-Stage-2/MapJoin-mapfile01--.hashtable
# 2024-11-11 05:56:19	Uploaded 1 File to: file:/tmp/root/bff1cb4e-e35a-4cd3-9ca2-729190a7d8d1/hive_2024-11-11_05-55-52_307_9126435370141163622-1/-local-10005/HashTable-Stage-2/MapJoin-mapfile01--.hashtable (28715 bytes)
# 2024-11-11 05:56:19	End of local task; Time Taken: 1.988 sec.
# Execution completed successfully
# MapredLocal task succeeded
# Launching Job 1 out of 1
# Number of reduce tasks not specified. Estimated from input data size: 10
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1731303223095_0003, Tracking URL = http://e6c4e6359247:8088/proxy/application_1731303223095_0003/
# Kill Command = /content/hadoop/bin/hadoop job  -kill job_1731303223095_0003
# Hadoop job information for Stage-2: number of mappers: 10; number of reducers: 10
# 2024-11-11 05:56:34,848 Stage-2 map = 0%,  reduce = 0%
# 2024-11-11 05:57:29,887 Stage-2 map = 7%,  reduce = 0%, Cumulative CPU 40.41 sec
# 2024-11-11 05:57:34,772 Stage-2 map = 13%,  reduce = 0%, Cumulative CPU 46.33 sec
# 2024-11-11 05:57:36,124 Stage-2 map = 17%,  reduce = 0%, Cumulative CPU 50.54 sec
# 2024-11-11 05:57:37,360 Stage-2 map = 20%,  reduce = 0%, Cumulative CPU 51.79 sec
# 2024-11-11 05:57:39,992 Stage-2 map = 27%,  reduce = 0%, Cumulative CPU 52.28 sec
# 2024-11-11 05:57:41,127 Stage-2 map = 40%,  reduce = 0%, Cumulative CPU 55.15 sec
# 2024-11-11 05:57:42,248 Stage-2 map = 53%,  reduce = 0%, Cumulative CPU 58.14 sec
# 2024-11-11 05:57:45,813 Stage-2 map = 60%,  reduce = 0%, Cumulative CPU 58.95 sec
# 2024-11-11 05:58:19,789 Stage-2 map = 60%,  reduce = 2%, Cumulative CPU 59.33 sec
# 2024-11-11 05:58:23,155 Stage-2 map = 60%,  reduce = 4%, Cumulative CPU 77.28 sec
# 2024-11-11 05:58:24,292 Stage-2 map = 70%,  reduce = 4%, Cumulative CPU 83.37 sec
# 2024-11-11 05:58:27,775 Stage-2 map = 73%,  reduce = 4%, Cumulative CPU 85.61 sec
# 2024-11-11 05:58:28,976 Stage-2 map = 73%,  reduce = 5%, Cumulative CPU 85.68 sec
# 2024-11-11 05:58:30,135 Stage-2 map = 80%,  reduce = 5%, Cumulative CPU 89.91 sec
# 2024-11-11 05:58:33,556 Stage-2 map = 87%,  reduce = 5%, Cumulative CPU 91.1 sec
# 2024-11-11 05:58:34,635 Stage-2 map = 100%,  reduce = 5%, Cumulative CPU 93.73 sec
# 2024-11-11 05:58:38,002 Stage-2 map = 100%,  reduce = 9%, Cumulative CPU 94.65 sec
# 2024-11-11 05:58:40,267 Stage-2 map = 100%,  reduce = 13%, Cumulative CPU 95.96 sec
# 2024-11-11 05:58:45,116 Stage-2 map = 100%,  reduce = 17%, Cumulative CPU 97.99 sec
# 2024-11-11 05:58:46,324 Stage-2 map = 100%,  reduce = 20%, Cumulative CPU 99.36 sec
# 2024-11-11 05:58:54,549 Stage-2 map = 100%,  reduce = 27%, Cumulative CPU 102.0 sec
# 2024-11-11 05:58:55,744 Stage-2 map = 100%,  reduce = 30%, Cumulative CPU 102.62 sec
# 2024-11-11 05:59:08,655 Stage-2 map = 100%,  reduce = 37%, Cumulative CPU 105.09 sec
# 2024-11-11 05:59:10,882 Stage-2 map = 100%,  reduce = 47%, Cumulative CPU 108.39 sec
# 2024-11-11 05:59:12,089 Stage-2 map = 100%,  reduce = 53%, Cumulative CPU 111.23 sec
# 2024-11-11 05:59:13,189 Stage-2 map = 100%,  reduce = 60%, Cumulative CPU 112.33 sec
# 2024-11-11 05:59:21,320 Stage-2 map = 100%,  reduce = 70%, Cumulative CPU 115.82 sec
# 2024-11-11 05:59:22,494 Stage-2 map = 100%,  reduce = 80%, Cumulative CPU 118.7 sec
# 2024-11-11 05:59:26,847 Stage-2 map = 100%,  reduce = 90%, Cumulative CPU 121.56 sec
# 2024-11-11 05:59:27,905 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 124.05 sec
# MapReduce Total cumulative CPU time: 2 minutes 4 seconds 50 msec
# Ended Job = job_1731303223095_0003
# MapReduce Jobs Launched:
# Stage-Stage-2: Map: 10  Reduce: 10   Cumulative CPU: 124.05 sec   HDFS Read: 2529395178 HDFS Write: 910 SUCCESS
# Total MapReduce CPU Time Spent: 2 minutes 4 seconds 50 msec
# OK
# gender	listeners
# f	43748
# m	63784
# Time taken: 217.89 seconds, Fetched: 2 row(s)

# %% [markdown]
# La cantidad de hombres que han escuchado alguna canción del artista más popular es 63784 y la cantidad de mujeres es 43748.

# %% [markdown]
# ## Actividad 3: Distribución por edad

# %%
# Inserte su código

# %%
# %%writefile actividad3.sql
#
# SELECT u.age, COUNT( l.user_id) AS listeners
# FROM lastfm_listens l
# JOIN lastfm_users u ON l.user_id = u.user_id
# WHERE l.artist_name = 'Radiohead' AND u.age is not null
# GROUP BY u.age
# ORDER BY u.age ASC;
# Out:
# Writing actividad3.sql

# %%
# !hive -f actividad3.sql
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
#
# Logging initialized using configuration in jar:file:/content/apache-hive-2.3.9-bin/lib/hive-common-2.3.9.jar!/hive-log4j2.properties Async: true
# WARNING: Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# Query ID = root_20241111055940_28865feb-198b-4657-8d9c-498b6c8c8a0a
# Total jobs = 2
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/content/apache-hive-2.3.9-bin/lib/log4j-slf4j-impl-2.6.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/content/hadoop-2.10.1/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# 2024-11-11 06:00:03	Starting to launch local task to process map join;	maximum memory = 477626368
# 2024-11-11 06:00:05	Dump the side-table for tag: 1 with group count: 286 into file: file:/tmp/root/a8afd28f-6446-444d-9f0d-08976525ea00/hive_2024-11-11_05-59-40_810_8285557609355391945-1/-local-10006/HashTable-Stage-2/MapJoin-mapfile01--.hashtable
# 2024-11-11 06:00:05	Uploaded 1 File to: file:/tmp/root/a8afd28f-6446-444d-9f0d-08976525ea00/hive_2024-11-11_05-59-40_810_8285557609355391945-1/-local-10006/HashTable-Stage-2/MapJoin-mapfile01--.hashtable (9169 bytes)
# 2024-11-11 06:00:05	End of local task; Time Taken: 2.0 sec.
# Execution completed successfully
# MapredLocal task succeeded
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 10
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1731303223095_0004, Tracking URL = http://e6c4e6359247:8088/proxy/application_1731303223095_0004/
# Kill Command = /content/hadoop/bin/hadoop job  -kill job_1731303223095_0004
# Hadoop job information for Stage-2: number of mappers: 10; number of reducers: 10
# 2024-11-11 06:00:19,520 Stage-2 map = 0%,  reduce = 0%
# 2024-11-11 06:01:16,641 Stage-2 map = 13%,  reduce = 0%, Cumulative CPU 43.08 sec
# 2024-11-11 06:01:17,884 Stage-2 map = 20%,  reduce = 0%, Cumulative CPU 46.16 sec
# 2024-11-11 06:01:23,813 Stage-2 map = 33%,  reduce = 0%, Cumulative CPU 52.85 sec
# 2024-11-11 06:01:24,906 Stage-2 map = 53%,  reduce = 0%, Cumulative CPU 54.5 sec
# 2024-11-11 06:01:26,033 Stage-2 map = 60%,  reduce = 0%, Cumulative CPU 55.29 sec
# 2024-11-11 06:02:00,055 Stage-2 map = 60%,  reduce = 2%, Cumulative CPU 55.58 sec
# 2024-11-11 06:02:01,146 Stage-2 map = 60%,  reduce = 4%, Cumulative CPU 55.87 sec
# 2024-11-11 06:02:03,341 Stage-2 map = 63%,  reduce = 4%, Cumulative CPU 61.54 sec
# 2024-11-11 06:02:04,445 Stage-2 map = 73%,  reduce = 4%, Cumulative CPU 74.22 sec
# 2024-11-11 06:02:05,545 Stage-2 map = 77%,  reduce = 4%, Cumulative CPU 80.29 sec
# 2024-11-11 06:02:06,662 Stage-2 map = 77%,  reduce = 5%, Cumulative CPU 80.39 sec
# 2024-11-11 06:02:10,127 Stage-2 map = 87%,  reduce = 5%, Cumulative CPU 84.4 sec
# 2024-11-11 06:02:11,224 Stage-2 map = 100%,  reduce = 5%, Cumulative CPU 86.02 sec
# 2024-11-11 06:02:12,439 Stage-2 map = 100%,  reduce = 10%, Cumulative CPU 86.36 sec
# 2024-11-11 06:02:18,093 Stage-2 map = 100%,  reduce = 13%, Cumulative CPU 87.75 sec
# 2024-11-11 06:02:20,362 Stage-2 map = 100%,  reduce = 17%, Cumulative CPU 90.05 sec
# 2024-11-11 06:02:21,492 Stage-2 map = 100%,  reduce = 20%, Cumulative CPU 91.26 sec
# 2024-11-11 06:02:33,683 Stage-2 map = 100%,  reduce = 30%, Cumulative CPU 94.1 sec
# 2024-11-11 06:02:41,748 Stage-2 map = 100%,  reduce = 40%, Cumulative CPU 96.53 sec
# 2024-11-11 06:02:42,977 Stage-2 map = 100%,  reduce = 50%, Cumulative CPU 99.14 sec
# 2024-11-11 06:02:47,736 Stage-2 map = 100%,  reduce = 60%, Cumulative CPU 101.94 sec
# 2024-11-11 06:02:53,353 Stage-2 map = 100%,  reduce = 80%, Cumulative CPU 107.1 sec
# 2024-11-11 06:02:56,569 Stage-2 map = 100%,  reduce = 90%, Cumulative CPU 109.63 sec
# 2024-11-11 06:02:57,624 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 111.59 sec
# MapReduce Total cumulative CPU time: 1 minutes 51 seconds 590 msec
# Ended Job = job_1731303223095_0004
# Launching Job 2 out of 2
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1731303223095_0005, Tracking URL = http://e6c4e6359247:8088/proxy/application_1731303223095_0005/
# Kill Command = /content/hadoop/bin/hadoop job  -kill job_1731303223095_0005
# Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
# 2024-11-11 06:03:12,188 Stage-3 map = 0%,  reduce = 0%
# 2024-11-11 06:03:20,832 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 2.25 sec
# 2024-11-11 06:03:27,217 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 4.48 sec
# MapReduce Total cumulative CPU time: 4 seconds 480 msec
# Ended Job = job_1731303223095_0005
# MapReduce Jobs Launched:
# Stage-Stage-2: Map: 10  Reduce: 10   Cumulative CPU: 111.59 sec   HDFS Read: 2529386888 HDFS Write: 1589 SUCCESS
# Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 4.48 sec   HDFS Read: 9370 HDFS Write: 675 SUCCESS
# Total MapReduce CPU Time Spent: 1 minutes 56 seconds 70 msec
# OK
# u.age	listeners
# 3	2
# 4	14
# 7	2
# 15	2
# 16	122
# 17	444
# 18	65
# 19	4514
# 20	5760
# 21	1589
# 22	7038
# 23	2552
# 24	1313
# 25	1289
# 26	2527
# 27	2360
# 28	1330
# 29	359
# 30	617
# 31	146
# 32	433
# 33	1441
# 34	404
# 35	1543
# 36	1962
# 38	422
# 39	213
# 42	13
# 48	35
# 75	109
# 103	1
# Time taken: 228.781 seconds, Fetched: 31 row(s)

# %% [markdown]
# 1543 usuarios de 35 años han escuchado al artista más popular que en este caso es Radiohead.
